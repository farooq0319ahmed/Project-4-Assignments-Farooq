# %% [markdown]
# <a href="https://colab.research.google.com/github/farooq0319ahmed/Project-4-Assignments-Farooq/blob/root/02_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("01_add_many_number.md")

def add_number(numbers)->int:
  num:int = 0
  for i in numbers:
    num += i
  return num

def main():
  numbers:list[int] = [1,2,3,4,5]
  sum = add_number(numbers)
  print(sum)

if __name__ == "__main__":
  main()
# Out:
# 01_add_many_number.md
# 15

# %%
print("02_double_list.md")

def main():
  numbers:list[int] = [1,2,3,4,5]
  for i in range(len(numbers)):
    index = numbers[i]
    numbers[i] = index * 2
  print(numbers)

if __name__ == "__main__":
  main()
# Out:
# 02_double_list.md
# [2, 4, 6, 8, 10]

# %%
print("04_flowing_with_data_structures.md")

def add_three_copies(lst,data):
  for i in range(3):
    lst.append(data)

def main():
  message = input("Enter a message to copy. ")
  lst = []
  print("Before list: ",lst)
  add_three_copies(lst,message)
  print("After lst: ",lst)

if __name__ == "__main__":
  main()
# Out:
# 04_flowing_with_data_structures.md
# Enter a message to copy. hello pakistan
# Before list:  []
# After lst:  ['hello pakistan', 'hello pakistan', 'hello pakistan']

# %%
print("05_get_first_element.md")

def get_first_element(lst):
  print(lst[0])

def get_lst():
  lst = []
  elem:str = input("Enter an element to add to the list. ")
  while elem != "":
    lst.append(elem)
    elem = input("Enter an element to add to the list. ")
  return lst

def main():
  lst = get_lst()
  get_first_element(lst)

if __name__ == "__main__":
  main()
# Out:
# 05_get_first_element.md
# Enter an element to add to the list. a
# Enter an element to add to the list. s
# Enter an element to add to the list. f
# Enter an element to add to the list. h
# Enter an element to add to the list. y
# Enter an element to add to the list. o
# Enter an element to add to the list. p
# Enter an element to add to the list. t
# Enter an element to add to the list.
# Enter an element to add to the list.
# a

# %%
print("06_get_last_element.md")

def get_last_element(lst):
  print(lst[-1])

def get_lst():
  lst = []
  elem:str = input("Enter an element to add to the list. ")
  while elem != "":
    lst.append(elem)
    elem = input("Enter an element to add to the list. ")
  return lst

def main():
  lst = get_lst()
  get_last_element(lst)

if __name__ == "__main__":
  main()
# Out:
# 06_get_last_element.md
# Enter an element to add to the list. h
# Enter an element to add to the list. j
# Enter an element to add to the list. i
# Enter an element to add to the list. o
# Enter an element to add to the list. r
# Enter an element to add to the list. w
# Enter an element to add to the list. k
# Enter an element to add to the list.
# k

# %%
print("07_get_list.md")

def main():
  lst = []
  val = input("Enter a value to add to the list. ")
  while val:
    lst.append(val)
    val = input("Enter a value to add to the list. ")
  print("Here's the list: ",lst)

if __name__ == "__main__":
  main()
# Out:
# 07_get_list.md
# Enter a value to add to the list. ali
# Enter a value to add to the list. farooq
# Enter a value to add to the list. amna
# Enter a value to add to the list. yusra
# Enter a value to add to the list. kiswah
# Enter a value to add to the list. yaseen
# Enter a value to add to the list.
# Here's the list:  ['ali', 'farooq', 'amna', 'yusra', 'kiswah', 'yaseen']

# %%
print("08_shorten.md")

MAX_LENGTH:int = 3
def shorten(lst):
  while len(lst) > MAX_LENGTH:
    last_element = lst.pop()
    print(last_element)

def get_lst():
  lst = []
  element = input("Enter an element to add to the list: ")
  while element != "":
    lst.append(element)
    element = input("Enter an element to add to the list: ")
  return lst

def main():
  lst = get_lst()
  shorten(lst)

if __name__ == "__main__":
  main()
# Out:
# 08_shorten.md
# Enter an element to add to the list: wdt
# Enter an element to add to the list: yji
# Enter an element to add to the list: pli
# Enter an element to add to the list: ijy
# Enter an element to add to the list: ygr
# Enter an element to add to the list: tfe
# Enter an element to add to the list: ygc
# Enter an element to add to the list: ijn
# Enter an element to add to the list: ljl
# Enter an element to add to the list:
# ljl
# ijn
# ygc
# tfe
# ygr
# ijy
