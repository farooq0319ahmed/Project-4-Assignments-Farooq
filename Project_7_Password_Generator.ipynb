# %% [markdown]
# <a href="https://colab.research.google.com/github/farooq0319ahmed/Project-4-Assignments-Farooq/blob/root/Project_7_Password_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = "".join(random.choice(characters) for _ in range(length))
    return password

length = int(input("Enter the desired password length: "))

if __name__ == "__main__":
    print("Generated Password:", generate_password(length))
# Out:
# Enter the desired password length: 7
# Generated Password: l'bqoLF
